# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

font = {'family': 'serif',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

# %%
def get_avg_perf(col_perf):
    avg_perf = []
    for i in range(len(col_perf[0])):
        avg_perf.append(np.mean([col_perf[j][i] for j in range(len(col_perf))]))
    return avg_perf

def seperate_poisoned(col_perf, num_poisoned):
    poisoned = []
    unpoisoned = []
    for i in range(len(col_perf)):
        if i < num_poisoned:
            poisoned.append(col_perf[i])
        else:
            unpoisoned.append(col_perf[i])
    return poisoned, unpoisoned

def get_avg_perf_poisoned(col_perf, num_poisoned):
    poisoned, unpoisoned = seperate_poisoned(col_perf, num_poisoned)
    return get_avg_perf(poisoned), get_avg_perf(unpoisoned)

# %%
with open('results/sfd-no-poisoning/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
p0_unpoisoned = get_avg_perf(col_perf)

# %%
with open('results/poison-variation/result_FEMNIST_balanced-p1/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID Poison', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
_, p1_unpoisoned = get_avg_perf_poisoned(col_perf, 1)

# %%
with open('results/poison-variation/result_FEMNIST_balanced-p2/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID Poison', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
_, p2_unpoisoned = get_avg_perf_poisoned(col_perf, 2)

# %%
with open('results/poison-variation/result_FEMNIST_balanced-p3/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID Poison', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
_, p3_unpoisoned = get_avg_perf_poisoned(col_perf, 3)

# %%
with open('results/sfd-poison/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID Poison', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
avg_poisoned_IID, avg_unpoisoned_IID = get_avg_perf_poisoned(col_perf, 4)

# %%
plt.figure(figsize=(8, 6))

plt.plot(p0_unpoisoned, label='0 Nodes Poisoned')
plt.plot(p1_unpoisoned, label='1 Nodes Poisoned')
plt.plot(p2_unpoisoned, label='2 Nodes Poisoned')
plt.plot(p3_unpoisoned, label='3 Nodes Poisoned')
plt.plot(avg_unpoisoned_IID, label='4 Nodes Poisoned')

plt.title('Non-poisoned Model Accuracy', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
with open('results/skd/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID skd', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
avg_poisoned_skd, avg_unpoisoned_skd = get_avg_perf_poisoned(col_perf, 4)

# %%
with open('results/skd-avg/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID skd', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
skd_avg_p, skd_avg_un = get_avg_perf_poisoned(col_perf, 4)

# %%
with open('results/skd-top25/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID skd', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
skd_top25_p, skd_top25_un = get_avg_perf_poisoned(col_perf, 4)

# %%
with open('results/skd-25to50/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID skd', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
skd_25to50_p, skd_25to50_un = get_avg_perf_poisoned(col_perf, 4)

# %%
with open('results/skd-w-avg/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID skd', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
skd_w_avg_p, skd_w_avg_un = get_avg_perf_poisoned(col_perf, 4)

# %%
plt.figure(figsize=(8, 6))

plt.plot(avg_poisoned_IID, label='Before SKD')
plt.plot(avg_poisoned_skd, label='SKD Fized')
plt.plot(skd_avg_p, label='SKD Avg')
plt.plot(skd_top25_p, label='SKD Top25')
plt.plot(skd_25to50_p, label='SKD 25to50')
plt.plot(skd_w_avg_p, label='SKD w Avg')

plt.title('Poisoned Model Accuracy', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.legend()
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8, 6))

plt.plot(avg_unpoisoned_IID, label='Before SKD')
plt.plot(avg_unpoisoned_skd, label='SKD Fixed')
plt.plot(skd_avg_un, label='SKD Avg')
plt.plot(skd_top25_un, label='SKD Top25')
plt.plot(skd_25to50_un, label='SKD 25to50')
plt.plot(skd_w_avg_un, label='SKD w Avg')

plt.title('Non-poisoned Model Accuracy', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
with open('results/ssfd/result_FEMNIST_balanced/col_performance.pkl', 'rb') as f:
    col_perf = pickle.load(f)

plt.figure(figsize=(8, 6))
for i in range(len(col_perf)):
    plt.plot(col_perf[i])

plt.title('FEMNIST IID ssfd', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.plot()
# Out:
# []

# %%
avg_poisoned_ssfd, avg_unpoisoned_ssfd = get_avg_perf_poisoned(col_perf, 4)

# %%
plt.figure(figsize=(8, 6))

plt.plot(avg_unpoisoned_ssfd, label='SSFD')
plt.plot(avg_unpoisoned_skd, label='SKD Fixed')
plt.plot(skd_avg_un, label='SKD Avg')
plt.plot(skd_top25_un, label='SKD Top25')
plt.plot(skd_25to50_un, label='SKD 25to50')
plt.plot(skd_w_avg_un, label='SKD w Avg')

plt.title('Non-poisoned Model Accuracy', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.legend(loc='best')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8, 6))

plt.plot(avg_poisoned_ssfd, label='SSFD')
plt.plot(avg_poisoned_skd, label='SKD Fized')
plt.plot(skd_avg_p, label='SKD Avg')
plt.plot(skd_top25_p, label='SKD Top25')
plt.plot(skd_25to50_p, label='SKD 25to50')
plt.plot(skd_w_avg_p, label='SKD w Avg')

plt.title('Poisoned Model Accuracy', fontdict=font)
plt.xlabel('No. of Epoch', fontdict=font)
plt.ylabel('Test Accuracy', fontdict=font)
plt.xticks(list(range(21)))
plt.legend()
plt.plot()
# Out:
# []
